# %% [markdown]
# # 1. Framing the problem
#
# ### Problem:
#
# #### There is a big demand for organizing themed parties. Quite often, the organizers are asked to theme a party by a decade, so people may feel as though they trully are at a party from the (distant) past. Usually, the organizers are asked to plan a party themed for the 80s or 90s, or something of that sort.
#
# ### Scope/Objective:
#
# #### When thinking of party, one of the first things that come to mind is the music. The music decides the mood on the dance floor and infuses the participants' hearts with a joyful rhythm.
#
# #### The organizers want to create playlists with songs that 'feel like a decade', even if they are not.
#
# ### (Spoilers!) How the problem will be solved (Spoilers!)
#
# #### The problem shall be solved in a supervised manner. The dataset will undergo needed transformations. From the transformed dataset, a set of features and labels will be selected. Different classification models will be trained to find the best one.
# #### The performance of the models will be tested by feeding in different songs, and seeing what decade they predict the song is from. This way, when the organizers have a list of songs they wish to select for a themed party, they can feeed the songs to the model, and see which ones match.

# %% [markdown]
# # 2. Getting data
#
# ### Data to be used represents a dataset of roughly 30k songs from Spotify. The data contains columns related to songs (names, artists, ids, date of release), but also metadata about the songs. The metadata in this context refers to such columns as 'danceability', 'mode', 'duration', 'energy', 'key', etc.
#
# ### Data was downloaded from kaggle:
# https://www.kaggle.com/datasets/joebeachcapital/30000-spotify-songs
#
# ### The information about the data can be seen in the cell below.
#
# #### It has 32833 rows of data, which should be more than enough for the purpose.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import precision_score

from imblearn.over_sampling import SMOTE, ADASYN, BorderlineSMOTE, SMOTENC

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import export_text
from sklearn.svm import SVC



from sklearn.preprocessing import PolynomialFeatures

from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.decomposition import PCA

data = pd.read_csv('spotify_songs.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3. Explore the data
#
# ### The exploration of data starts below.
# #### It can be seen that very few data is missing. There are only 0.014% of missing data in some irrelevant columns, such as 'track_name', 'track_artist' and 'track_album_name'
# #### Moreover, some plots can be seen below, which can make the reader more familiar with the data
#
# ### A new column is created. The new column is called 'decade' and represents the binning of the 'track_album_release_date' column from the original dataset.
#
# ### Heat maps regarding correlation are also presented.
#
# ### After the data is divided into features and labels, the features (X) are scaled. The labels (Y) are scaled as well. Scaling helps in model performance quite a lot.

# %% [markdown]
# ### Percentage of missing values
# #### We can see that barely 0.014% of values are missing for some of the columns.

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize lists to store the column names and missing percentages
column_names = []
missing_percentages = []

for column_name, column in data.items():
    column_names.append(column_name)

    # Percentage of missing values
    missing_percentage = (column.isnull().sum() / len(data)) * 100
    missing_percentages.append(missing_percentage)

# Create a bar plot for missing percentages
plt.figure(figsize=(12, 6))
sns.barplot(x=column_names, y=missing_percentages)
plt.xticks(rotation=90)
plt.title('Percentage of Missing Values')
plt.ylabel('Percentage')

# Show the plot
plt.show()

# %% [markdown]
# ### Songs by genre.
# #### This information will help us see how the songs are distributed among genres, and if making a multiclass classification makes sense

# %%
country_counts = data['playlist_genre'].value_counts()
plt.figure(figsize=(12, 6))
country_counts.plot(kind='bar')
plt.title('Number of Tracks by Genre')
plt.xlabel('Genre')
# plt.ylabel('Number of Tracks')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ### Songs by subgenre.
# #### This information will help us see how the songs are distributed among subgenres, and if making a multiclass classification makes sense

# %%
country_counts = data['playlist_subgenre'].value_counts()
plt.figure(figsize=(12, 6))
country_counts.plot(kind='bar')
plt.title('Number of Tracks by Subgenre')
plt.xlabel('Subgenre')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Adding new Feature called 'decade'
# #### This feature is a binning of song by decade, starting from the earliest decade found in the dataset

# %%
# earliest_date = data['track_album_release_date'].min() ## checking the earliest date

data['decade'] = data['track_album_release_date'].str[:4].astype(int) // 10 * 10

# Create bins for each decade
bins = {
    1950: "50s",
    1960: "60s",
    1970: "70s",
    1980: "80s",
    1990: "90s",
    2000: "2000s",
    2010: "2010s",
    2020: "2020s"
}

data['decade'] = data['decade'].map(bins)

# %% [markdown]
# ### Songs by decade

# %%
country_counts = data['decade'].value_counts()
plt.figure(figsize=(12, 6))
country_counts.plot(kind='bar')
plt.title('Number of Tracks by Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Feature Correlation
# ### Using only numeric features

# %%
numeric_data = data.select_dtypes(include=[np.number])
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### With textual data

# %%
numeric_data = data.copy()

# Initialize LabelEncoder
label_encoder1 = LabelEncoder()

# Iterate over each column to identify non-numeric columns
for column in numeric_data.columns:
    if numeric_data[column].dtype == 'object':
        # Apply label encoding to non-numeric columns
        numeric_data[column] = label_encoder1.fit_transform(numeric_data[column].astype(str))

# Calculate the correlation matrix for the numeric data
correlation_matrix_numeric = numeric_data.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(30, 20))
sns.heatmap(correlation_matrix_numeric, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap (Numeric Encoded)')
# Position x-axis labels at the top
plt.tick_params(axis='x', labeltop=True)
plt.show()

# %% [markdown]
# # 4. Preparing data
#
# #### Some columns are dropped, as can be seen below. X and Y (features and labels) are selected.
#
# #### For testing purposes, there are two label datasets. One, that has the labels in one column, and one that one-encodes them into 6 columns. Testing has proven that 1 column works better with classification, and 6 columns work better with neural networks (although no neural networks are presented here)
#
# #### Data is split into training and testing sets. Then the X_train and X_test are scaled.
#
#
# #### After Y is encoded:

# %%
# # Original Values  Encoded Values
#            2010s               1
#            2000s               0
#            2020s               2
#              90s               7
#              80s               6
#              70s               5
#              60s               4
#              50s               3

# %% [markdown]
# # Dropping features that are irrelevant from the first look

# %%
columns_to_drop = ['track_id', 'track_name', 'track_artist', 'track_album_id',
                   'track_album_name', 'track_album_release_date'
                   ,'playlist_name', 'playlist_id', 'track_popularity','playlist_subgenre','playlist_genre']

relevant_data = data.drop(columns=columns_to_drop)
relevant_data
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634     1       0.0583      0.102000
# 1             0.726   0.815   11    -4.969     1       0.0373      0.072400
# 2             0.675   0.931    1    -3.432     0       0.0742      0.079400
# 3             0.718   0.930    7    -3.778     1       0.1020      0.028700
# 4             0.650   0.833    1    -4.672     1       0.0359      0.080300
# ...             ...     ...  ...       ...   ...          ...           ...
# 32828         0.428   0.922    2    -1.814     1       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462     1       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899     0       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361     1       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms decade
# 0              0.000000    0.0653   0.5180  122.036       194754  2010s
# 1              0.004210    0.3570   0.6930   99.972       162600  2010s
# 2              0.000023    0.1100   0.6130  124.008       176616  2010s
# 3              0.000009    0.2040   0.2770  121.956       169093  2010s
# 4              0.000000    0.0833   0.7250  123.976       189052  2010s
# ...                 ...       ...      ...      ...          ...    ...
# 32828          0.000000    0.0668   0.2100  128.170       204375  2010s
# 32829          0.004270    0.3750   0.4000  128.041       353120  2010s
# 32830          0.000001    0.1500   0.4360  127.989       210112  2010s
# 32831          0.127000    0.3430   0.3080  128.008       367432  2010s
# 32832          0.341000    0.7420   0.0894  127.984       337500  2010s
#
# [32833 rows x 13 columns]

# %% [markdown]
# ## Transforming non-numeric to numeric

# %%
numeric_data = relevant_data.copy()

# Initialize LabelEncoder
label_encoder1 = LabelEncoder()## this performs label encoding
## one hot encoding transforms each value from a column into an int

# Iterate over each column to identify non-numeric columns
for column in numeric_data.columns:
    if numeric_data[column].dtype == 'object':
        # Apply label encoding to non-numeric columns
        numeric_data[column] = label_encoder1.fit_transform(numeric_data[column].astype(str))

numeric_data
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634     1       0.0583      0.102000
# 1             0.726   0.815   11    -4.969     1       0.0373      0.072400
# 2             0.675   0.931    1    -3.432     0       0.0742      0.079400
# 3             0.718   0.930    7    -3.778     1       0.1020      0.028700
# 4             0.650   0.833    1    -4.672     1       0.0359      0.080300
# ...             ...     ...  ...       ...   ...          ...           ...
# 32828         0.428   0.922    2    -1.814     1       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462     1       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899     0       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361     1       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms  decade
# 0              0.000000    0.0653   0.5180  122.036       194754       1
# 1              0.004210    0.3570   0.6930   99.972       162600       1
# 2              0.000023    0.1100   0.6130  124.008       176616       1
# 3              0.000009    0.2040   0.2770  121.956       169093       1
# 4              0.000000    0.0833   0.7250  123.976       189052       1
# ...                 ...       ...      ...      ...          ...     ...
# 32828          0.000000    0.0668   0.2100  128.170       204375       1
# 32829          0.004270    0.3750   0.4000  128.041       353120       1
# 32830          0.000001    0.1500   0.4360  127.989       210112       1
# 32831          0.127000    0.3430   0.3080  128.008       367432       1
# 32832          0.341000    0.7420   0.0894  127.984       337500       1
#
# [32833 rows x 13 columns]

# %% [markdown]
# # Selecting features and labels
# ### X has numeric data about danceability, energy, key, etc.
# ### Y has the decade column
#
# ### Because there are few instances of some classes, it might be a good idea to resample some instances. The way it is doen with RandomOverSampler, is that it will resample the minority classes

# %%
# # relevant_data
# numeric_data

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler


X = numeric_data.drop(columns=[ 'decade'])
Y = numeric_data['decade']

############################################################
oversampler = RandomOverSampler(random_state=42)
## creates synthetic values to compensate for missing instances in classes
# other oversamplers can be used, such as SMOTE, ADASYN, BorderlineSMOTE, SMOTENC

# Resample the dataset to balance the number of instances for each decade
X_resampled, y_resampled = oversampler.fit_resample(X, Y)

X = X_resampled
Y = y_resampled
#################################################

# %%
# # Get unique values before encoding
original_values = relevant_data['decade'].unique()

# Get unique values after encoding
encoded_values = numeric_data['decade'].unique()

# Create a DataFrame to display translations (before and after encoding)
translations = pd.DataFrame({'Original Values': original_values, 'Encoded Values': encoded_values})

print(translations)
# Out:
#   Original Values  Encoded Values
# 0           2010s               1
# 1           2000s               0
# 2           2020s               2
# 3             90s               7
# 4             80s               6
# 5             70s               5
# 6             60s               4
# 7             50s               3

# %%
Y = pd.DataFrame(Y)
country_counts = Y['decade'].value_counts()
plt.figure(figsize=(12, 6))
country_counts.plot(kind='bar')
plt.title('Number of Tracks by Decade')
plt.xlabel('Decade')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ### Y will stay as 1 columns. This should be done if numeric_data is used for X and Y, and not relevant_data(which still has text columns)

# %%
# from sklearn.preprocessing import LabelEncoder
#
# label_encoder2 = LabelEncoder()
# Y_one_column = label_encoder2.fit_transform(Y)
# Y_one_column
#
#
# y_decoded =label_encoder2.inverse_transform(Y_one_column)
# y_decoded

# %% [markdown]
# ### Transformig the two Ys into dataframes. Scaling X

# %%
Y_one_column = pd.DataFrame(Y)

# %%
from sklearn.model_selection import train_test_split


X_train, X_temp, label_train, label_temp = train_test_split(X, Y_one_column, test_size=0.2, random_state=50)
X_val, X_test, label_val, label_test = train_test_split(X_temp, label_temp, test_size=0.2, random_state=50)

print("Number of data points in training set, validation set, and test set, respectively: {}, {}, and {}".format(X_train.shape[0],
                                                                                                              X_val.shape[0],
                                                                                                              X_test.shape[0]))
# Out:
# Number of data points in training set, validation set, and test set, respectively: 148569, 29714, and 7429

# %%
import matplotlib.pyplot as plt


# Get the sizes of each dataset
train_size = X_train.shape[0]
val_size = X_val.shape[0]
test_size = X_test.shape[0]

# Set up the data for plotting
datasets = ['Training Set', 'Validation Set', 'Test Set']
sizes = [train_size, val_size, test_size]

# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(datasets, sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Datasets')
plt.ylabel('Number of Data Points')
plt.title('Distribution of Data Points in Different Sets')
plt.show()

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# # 5. Short-list promising models
#
# #### Notice that after oversampling, the previously underperforming classes started performing much better
#
# #### All models have trouble predicting songs in the 50s, as there is little data from that decade.
#
# #### Feature selection using sklearn doesn't help much with the accuracy. In fact, if we use a dataset with selected features, the accuracy drops.
#
# ## The accuracies from below are from the models before the oversampling technique was applied!
# #### The actual performance can be found in step 6, or by looking at how the models have performed below.
#
# ## KNN:
# #### Accuracy: 71.5% - 72.5%
# #### Most significant variables: n_neighbours, metric
# #### Errors: lwo precision and recall on most classes. The high precision of the model is due to class 1. Even so, the model performs quire accurately when testing with random songs.
#
#
# ## NB:
# #### Accuracy: 69.8%
# #### Most significant variables:
# #### Errors: Performs very badly. High precision is due to predicting class 1, while all other classes have very low prediction and very low recall. This means that NB can only predict one class.
#
#
#
# ## Logistic regression:
# #### Accuracy: 72%
# #### Most significant variables: solver, penalty, c
# #### Errors: Just like NB, low precision and recall on most classes. High accuracy is due to class 1, and maybe a bit other classes.
#
# ## Decision Trees:
# #### Accuracy: 71.2%
# #### Most significant variables: max_depth, min_samples_split, min_samples_leaf, criterion
# #### Errors: Again the same problem of low precision and recall on some classes. This is due to missing data most likely
#
#
# ## Random Forest:
# #### Accuracy: 79.2%
# #### Most significant variables: n_estimators, max_features
# #### Errors: Surprisingly, the precision and recall increase dramatically when compared to other models. even though they are not perfect, the classification is done much better.
#
# ## Support Vector machines:
# #### Accuracy: 74.4%
# #### Most significant variables: kernel, c
# #### Just like Random Forests, the precision and recall are much better than the rest of the models. Class 3 (50s) is very badly predicted, because there is little data about those songs.
#
#
# ## In conclusion, it can be seen that one of the biggest issues (with most of the models) is that data is missing. It is hard for the model to classify all songs, because for example there are many more songs from 2010s than from 50s in the dataset.

# %% [markdown]
# # KNN

# %%
for x in range (1,15):
    knn = KNeighborsClassifier(n_neighbors=x)
    knn.fit(X_train, label_train)
    print(x , ":")
    print("Model accuracy on the original data: {}".format(knn.score(X_val, label_val)))
# Out:
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 1 :
# Model accuracy on the original data: 0.9751295685535438
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 2 :
# Model accuracy on the original data: 0.9677593053779363
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 3 :
# Model accuracy on the original data: 0.9595476879585381
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 4 :
# Model accuracy on the original data: 0.9524466581409436
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 5 :
# Model accuracy on the original data: 0.9428552197617285
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 6 :
# Model accuracy on the original data: 0.9365955441879249
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 7 :
# Model accuracy on the original data: 0.9272060308272195
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 8 :
# Model accuracy on the original data: 0.9209127010836643
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 9 :
# Model accuracy on the original data: 0.9108164501581746
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 10 :
# Model accuracy on the original data: 0.9023692535505149
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 11 :
# Model accuracy on the original data: 0.8938884027731036
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 12 :
# Model accuracy on the original data: 0.8875950730295483
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 13 :
# Model accuracy on the original data: 0.8797873056471697
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 14 :
# Model accuracy on the original data: 0.8732920508851046

# %%
knn_test = KNeighborsClassifier(n_neighbors=3, metric='manhattan')
# {'manhattan', 'minkowski', 'sqeuclidean', 'dice', 'p', 'chebyshev', 'l2', 'hamming', 'jaccard', 'euclidean', 'l1', 'kulsinski', 'haversine', 'nan_euclidean', 'cosine', 'russellrao', 'braycurtis', 'seuclidean', 'rogerstanimoto', 'wminkowski', 'canberra', 'precomputed', 'matching', 'infinity', 'pyfunc', 'cityblock', 'sokalmichener', 'mahalanobis', 'sokalsneath', 'correlation', 'yule'}
#neighbours between 1 and 21
# metric in [‘euclidean’, ‘manhattan’, ‘minkowski’]
##minkowski or manhattan metric seems to output the best accuracy, but not by much
knn_test.fit(X_train, label_train)

####validating the model
val_predictions = knn_test.predict(X_val)
val_accuracy = accuracy_score(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)

# Print the results
print("Validation Accuracy:", val_accuracy)

print("Classification Report:")
print(classification_rep)
print(conf_matrix)
# Out:
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Validation Accuracy: 0.9597832671467995
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      3813
#            1       0.98      0.72      0.83      3653
#            2       0.96      1.00      0.98      3675
#            3       1.00      1.00      1.00      3662
#            4       1.00      1.00      1.00      3697
#            5       0.98      1.00      0.99      3683
#            6       0.97      0.99      0.98      3700
#            7       0.94      1.00      0.97      3831
#
#     accuracy                           0.96     29714
#    macro avg       0.96      0.96      0.96     29714
# weighted avg       0.96      0.96      0.96     29714
#
# [[3690   40    8    0    3   14   17   41]
#  [ 519 2621  143    0   14   60   96  200]
#  [   0    0 3675    0    0    0    0    0]
#  [   0    0    0 3662    0    0    0    0]
#  [   0    0    0    0 3697    0    0    0]
#  [   1    0    0    0    0 3682    0    0]
#  [  15    0    0    0    0    0 3676    9]
#  [   2    2    0    0    0    6    5 3816]]

# %% [markdown]
# ### Checking for over-under fitting

# %%
train_predictions = knn_test.predict(X_train)
predictions = knn_test.predict(X_test)

average = 'weighted'


# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average=average)
val_precision = precision_score(label_val, val_predictions, average=average)

# Evaluate precision on the test set
test_precision = precision_score(label_test, predictions, average=average)

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Validation Data:", val_precision)
print("Precision on Test Data:", test_precision)
# Out:
# Precision on Train Data: 0.9782891657293505
# Precision on Validation Data: 0.961872204726383
# Precision on Test Data: 0.9646696494616962

# %% [markdown]
# ## Making Predictions

# %%
random_song = np.array([0.31,	0.7,	9,	-5.678,	1,	0.047,	0.011,	0.00965,	0.0828,	0.763,	188.386,	255493])

random_song = random_song.reshape(1,-1)
random_song_scaled = scaler.transform(random_song)
prediction = knn_test.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# prediction
# Out:
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['80s'], dtype=object)

# %% [markdown]
# # Naive Bayes.

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# Y_bayes = Y_one_column
# X_train_bayes, X_test_bayes, label_train_bayes, label_test_bayes = train_test_split(X, Y_bayes, test_size=0.2,random_state=50)


nb = GaussianNB()
# nb = BernoulliNB() ## worse that Guassian
# nb = MultinomialNB()## cannot use multinomial because of negative values
nb.fit(X_train, label_train)

val_predictions = nb.predict(X_val)

val_accuracy = accuracy_score(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)

# Print the results
print("Accuracy:", val_accuracy)
print("Classification Report:")
print(classification_rep)
print(conf_matrix)

print("Model accuracy on the original data: {}".format(nb.score(X_val,label_val)))
# Out:
# Accuracy: 0.43063875614188596
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.31      0.31      3813
#            1       0.39      0.20      0.27      3653
#            2       0.49      0.37      0.42      3675
#            3       0.99      1.00      0.99      3662
#            4       0.40      0.39      0.39      3697
#            5       0.28      0.38      0.32      3683
#            6       0.29      0.51      0.37      3700
#            7       0.46      0.30      0.36      3831
#
#     accuracy                           0.43     29714
#    macro avg       0.45      0.43      0.43     29714
# weighted avg       0.45      0.43      0.43     29714
#
# [[1178  244  192    6  247  421  946  579]
#  [ 773  735 1020    3  281  196  420  225]
#  [ 709  544 1375    2  363  187  322  173]
#  [   0    0    0 3662    0    0    0    0]
#  [ 159  113   42    0 1426 1436  456   65]
#  [ 190   67   38   20  648 1389 1255   76]
#  [ 282   85   43    5  303  857 1877  248]
#  [ 581   79  101    1  261  534 1120 1154]]
# Model accuracy on the original data: 0.43063875614188596
# c:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Checking for over-under fitting. Poor performance

# %%
train_predictions = nb.predict(X_train)
test_predictions = nb.predict(X_test)

# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average='weighted')
test_precision = precision_score(label_test, test_predictions, average='weighted')
val_precision = precision_score(label_val, val_predictions, average='weighted')

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Test Data:", test_precision)
print("Precision on Validation Data:", val_precision)
# Out:
# Precision on Train Data: 0.44703814689758353
# Precision on Test Data: 0.4546124410094397
# Precision on Validation Data: 0.4501002304348549

# %% [markdown]
# ### Logistic Regression

# %%
logistic_regression_model = LogisticRegression(solver='lbfgs', penalty='none', C=0.1)
#lbfgs is faster than newton

## None of the hyperparameters really change the accuracy

# solver in [‘newton-cg’, ‘lbfgs’, ‘liblinear’, ‘sag’, ‘saga’]
# penalty in [‘none’, ‘l1’, ‘l2’, ‘elasticnet’]
# C in [100, 10, 1.0, 0.1, 0.01]

logistic_regression_model.fit(X_train,label_train )
val_predictions = logistic_regression_model.predict(X_val)

val_accuracy = accuracy_score(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)

# Print the results
print("Accuracy:", val_accuracy)
print("Classification Report:")
print(classification_rep)
print(conf_matrix)
# Out:
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\linear_model\_logistic.py:1181: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.47008144309079897
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.33      0.33      3813
#            1       0.35      0.30      0.32      3653
#            2       0.46      0.54      0.50      3675
#            3       1.00      1.00      1.00      3662
#            4       0.47      0.58      0.52      3697
#            5       0.33      0.27      0.29      3683
#            6       0.37      0.43      0.40      3700
#            7       0.43      0.33      0.37      3831
#
#     accuracy                           0.47     29714
#    macro avg       0.47      0.47      0.47     29714
# weighted avg       0.47      0.47      0.47     29714
#
# [[1274  676  300    6  323  216  435  583]
#  [ 632 1100 1315    1  214   60  122  209]
#  [ 356  824 1974    0  169   67  103  182]
#  [   0    0    0 3662    0    0    0    0]
#  [ 120  100  302    0 2127  712  250   86]
#  [ 257   77  190    3  957  986 1030  183]
#  [ 455  139   49    0  439  638 1587  393]
#  [ 722  219  168    0  308  352  804 1258]]
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Checking for over-under fitting.

# %%
train_predictions = logistic_regression_model.predict(X_train)
test_predictions = logistic_regression_model.predict(X_test)


# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average='weighted')

# Evaluate precision on the test set
test_precision = precision_score(label_test, test_predictions, average='weighted')
val_precision = precision_score(label_val, val_predictions, average='weighted')

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Test Data:", test_precision)
print("Precision on Validation Data:", val_precision)
# Out:
# Precision on Train Data: 0.46416054260515144
# Precision on Test Data: 0.4647295881342049
# Precision on Validation Data: 0.46601043706729167

# %% [markdown]
# ### Decision Trees

# %%
decision_tree_model = DecisionTreeClassifier(max_depth=19
                                            # max_depth=5
                                             ,min_samples_split=9,
                                             min_samples_leaf=3
                                             # ,max_features='log2'
                                             ,random_state=42,
                                             criterion='entropy',
                                             )
# he 'criterion' parameter of DecisionTreeClassifier must be a str among {'log_loss', 'entropy', 'gini'}

dtc = decision_tree_model.fit(X_train, label_train)

# Make predictions on the test set
val_predictions = decision_tree_model.predict(X_val)

# Evaluate the model
val_accuracy = accuracy_score(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)


# Print the results
print("Validation Accuracy:", val_accuracy)
print("Classification Report:")
print(classification_rep)

conf_matrix = confusion_matrix(label_val, val_predictions)

# Print the results
print(conf_matrix)

# Print the decision tree rules
tree_rules = export_text(decision_tree_model, feature_names=list(X.columns))
print("Decision Tree Rules:")
print(tree_rules)
# Out:
# Validation Accuracy: 0.9509995288416235
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      3813
#            1       0.93      0.72      0.81      3653
#            2       0.95      1.00      0.97      3675
#            3       1.00      1.00      1.00      3662
#            4       1.00      1.00      1.00      3697
#            5       0.97      1.00      0.98      3683
#            6       0.96      0.99      0.97      3700
#            7       0.93      0.98      0.95      3831
#
#     accuracy                           0.95     29714
#    macro avg       0.95      0.95      0.95     29714
# weighted avg       0.95      0.95      0.95     29714
#
# [[3526  140    9    0    0   25   56   57]
#  [ 493 2624  186    0   12   64   81  193]
#  [   0    9 3666    0    0    0    0    0]
#  [   0    0    0 3662    0    0    0    0]
#  [   0    0    0    0 3697    0    0    0]
#  [   0    6    0    0    0 3673    4    0]
#  [   3    0    0    0    0   13 3655   29]
#  [   9   28    1    0    0   26   12 3755]]
# Decision Tree Rules:
# |--- duration_ms <= -0.94
# |   |--- valence <= 1.19
# |   |   |--- danceability <= 0.60
# |   |   |   |--- valence <= -0.03
# |   |   |   |   |--- speechiness <= -0.65
# |   |   |   |   |   |--- danceability <= -0.52
# |   |   |   |   |   |   |--- speechiness <= -0.71
# |   |   |   |   |   |   |   |--- liveness <= -0.22
# |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |--- liveness >  -0.22
# |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |--- speechiness >  -0.71
# |   |   |   |   |   |   |   |--- acousticness <= -0.11
# |   |   |   |   |   |   |   |   |--- energy <= -1.90
# |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- energy >  -1.90
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- acousticness >  -0.11
# |   |   |   |   |   |   |   |   |--- valence <= -1.60
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- valence >  -1.60
# |   |   |   |   |   |   |   |   |   |--- loudness <= -1.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- loudness >  -1.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- danceability >  -0.52
# |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |--- duration_ms <= -1.08
# |   |   |   |   |   |   |   |   |--- energy <= -1.14
# |   |   |   |   |   |   |   |   |   |--- tempo <= -0.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- tempo >  -0.61
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- energy >  -1.14
# |   |   |   |   |   |   |   |   |   |--- loudness <= 0.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- loudness >  0.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |--- duration_ms >  -1.08
# |   |   |   |   |   |   |   |   |--- acousticness <= 1.97
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- acousticness >  1.97
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |--- speechiness <= -0.66
# |   |   |   |   |   |   |   |   |--- valence <= -1.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- valence >  -1.85
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- speechiness >  -0.66
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- speechiness >  -0.65
# |   |   |   |   |   |--- danceability <= -0.70
# |   |   |   |   |   |   |--- speechiness <= 0.67
# |   |   |   |   |   |   |   |--- tempo <= 1.18
# |   |   |   |   |   |   |   |   |--- liveness <= -0.54
# |   |   |   |   |   |   |   |   |   |--- danceability <= -1.32
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |--- danceability >  -1.32
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- liveness >  -0.54
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 2.67
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- acousticness >  2.67
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= -2.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  -2.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- tempo >  1.18
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.89
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- energy >  1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.89
# |   |   |   |   |   |   |   |   |   |--- tempo <= 1.34
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |   |--- energy >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |--- tempo >  1.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- speechiness >  0.67
# |   |   |   |   |   |   |   |--- danceability <= -1.37
# |   |   |   |   |   |   |   |   |--- liveness <= 0.03
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- liveness >  0.03
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- danceability >  -1.37
# |   |   |   |   |   |   |   |   |--- tempo <= 1.35
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- tempo >  1.35
# |   |   |   |   |   |   |   |   |   |--- mode <= -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- mode >  -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- danceability >  -0.70
# |   |   |   |   |   |   |--- duration_ms <= -1.45
# |   |   |   |   |   |   |   |--- danceability <= 0.53
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.81
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.72
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.72
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.81
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.83
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.83
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- danceability >  0.53
# |   |   |   |   |   |   |   |   |--- duration_ms <= -1.49
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- duration_ms >  -1.49
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- duration_ms >  -1.45
# |   |   |   |   |   |   |   |--- key <= -1.43
# |   |   |   |   |   |   |   |   |--- valence <= -0.07
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.77
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- valence >  -0.07
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- key >  -1.43
# |   |   |   |   |   |   |   |   |--- energy <= 1.46
# |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.64
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.64
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- energy >  1.46
# |   |   |   |   |   |   |   |   |   |--- tempo <= 0.81
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- energy >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- tempo >  0.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |--- valence >  -0.03
# |   |   |   |   |--- acousticness <= -0.19
# |   |   |   |   |   |--- danceability <= -0.12
# |   |   |   |   |   |   |--- speechiness <= -0.39
# |   |   |   |   |   |   |   |--- loudness <= -0.63
# |   |   |   |   |   |   |   |   |--- speechiness <= -0.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- speechiness >  -0.50
# |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |--- loudness >  -0.63
# |   |   |   |   |   |   |   |   |--- duration_ms <= -1.08
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- valence >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |--- duration_ms >  -1.08
# |   |   |   |   |   |   |   |   |   |--- liveness <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- liveness >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- speechiness >  -0.39
# |   |   |   |   |   |   |   |--- energy <= 1.43
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.55
# |   |   |   |   |   |   |   |   |   |--- tempo <= -0.73
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- tempo >  -0.73
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.55
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- energy >  1.43
# |   |   |   |   |   |   |   |   |--- energy <= 1.59
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  1.59
# |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |--- danceability >  -0.12
# |   |   |   |   |   |   |--- danceability <= 0.06
# |   |   |   |   |   |   |   |--- valence <= 0.60
# |   |   |   |   |   |   |   |   |--- duration_ms <= -1.40
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- duration_ms >  -1.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- valence >  0.60
# |   |   |   |   |   |   |   |   |--- mode <= -0.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- mode >  -0.29
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- danceability >  0.06
# |   |   |   |   |   |   |   |--- liveness <= -0.12
# |   |   |   |   |   |   |   |   |--- valence <= 1.01
# |   |   |   |   |   |   |   |   |   |--- loudness <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loudness >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- valence >  1.01
# |   |   |   |   |   |   |   |   |   |--- mode <= -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |--- mode >  -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- liveness >  -0.12
# |   |   |   |   |   |   |   |   |--- speechiness <= -0.49
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.84
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- valence >  0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- speechiness >  -0.49
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- energy <= -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- energy >  -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- acousticness >  -0.19
# |   |   |   |   |   |--- duration_ms <= -1.04
# |   |   |   |   |   |   |--- speechiness <= -0.64
# |   |   |   |   |   |   |   |--- duration_ms <= -1.08
# |   |   |   |   |   |   |   |   |--- loudness <= -1.17
# |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- loudness >  -1.17
# |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- duration_ms >  -1.08
# |   |   |   |   |   |   |   |   |--- duration_ms <= -1.06
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- duration_ms >  -1.06
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- speechiness >  -0.64
# |   |   |   |   |   |   |   |--- speechiness <= 0.10
# |   |   |   |   |   |   |   |   |--- energy <= -1.21
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 1.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  1.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  -1.21
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.63
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -2.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -2.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.63
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- speechiness >  0.10
# |   |   |   |   |   |   |   |   |--- duration_ms <= -1.12
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.32
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 1.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  1.87
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.32
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- duration_ms >  -1.12
# |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- duration_ms >  -1.04
# |   |   |   |   |   |   |--- duration_ms <= -1.00
# |   |   |   |   |   |   |   |--- energy <= -0.82
# |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |--- energy >  -0.82
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- duration_ms >  -1.00
# |   |   |   |   |   |   |   |--- liveness <= -0.54
# |   |   |   |   |   |   |   |   |--- liveness <= -0.68
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- liveness >  -0.68
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- liveness >  -0.54
# |   |   |   |   |   |   |   |   |--- energy <= 0.82
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  0.82
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- danceability >  0.60
# |   |   |   |--- valence <= 0.64
# |   |   |   |   |--- tempo <= -0.28
# |   |   |   |   |   |--- speechiness <= 2.48
# |   |   |   |   |   |   |--- duration_ms <= -0.98
# |   |   |   |   |   |   |   |--- acousticness <= -0.76
# |   |   |   |   |   |   |   |   |--- valence <= -0.70
# |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.85
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- valence >  -0.70
# |   |   |   |   |   |   |   |   |   |--- key <= -1.43
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- key >  -1.43
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- acousticness >  -0.76
# |   |   |   |   |   |   |   |   |--- energy <= -2.44
# |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.59
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  -2.44
# |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.63
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.63
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- duration_ms >  -0.98
# |   |   |   |   |   |   |   |--- key <= -0.30
# |   |   |   |   |   |   |   |   |--- tempo <= -0.94
# |   |   |   |   |   |   |   |   |   |--- liveness <= -0.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- liveness >  -0.64
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= -0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  -0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- tempo >  -0.94
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- key >  -0.30
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- speechiness >  2.48
# |   |   |   |   |   |   |--- speechiness <= 3.52
# |   |   |   |   |   |   |   |--- duration_ms <= -0.95
# |   |   |   |   |   |   |   |   |--- liveness <= -0.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- liveness >  -0.14
# |   |   |   |   |   |   |   |   |   |--- mode <= -0.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- mode >  -0.29
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration_ms >  -0.95
# |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |--- speechiness >  3.52
# |   |   |   |   |   |   |   |--- loudness <= 1.08
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- loudness >  1.08
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- tempo >  -0.28
# |   |   |   |   |   |--- speechiness <= 3.86
# |   |   |   |   |   |   |--- key <= -1.14
# |   |   |   |   |   |   |   |--- tempo <= -0.22
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- tempo >  -0.22
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- key >  -1.14
# |   |   |   |   |   |   |   |--- duration_ms <= -1.39
# |   |   |   |   |   |   |   |   |--- danceability <= 0.67
# |   |   |   |   |   |   |   |   |   |--- danceability <= 0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- danceability >  0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- danceability >  0.67
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- duration_ms >  -1.39
# |   |   |   |   |   |   |   |   |--- energy <= -0.93
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  -0.93
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.41
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- valence >  0.41
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- speechiness >  3.86
# |   |   |   |   |   |   |--- duration_ms <= -1.41
# |   |   |   |   |   |   |   |--- tempo <= 0.18
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- tempo >  0.18
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- duration_ms >  -1.41
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- valence >  0.64
# |   |   |   |   |--- key <= -0.30
# |   |   |   |   |   |--- speechiness <= 0.01
# |   |   |   |   |   |   |--- energy <= 0.21
# |   |   |   |   |   |   |   |--- energy <= -0.79
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- energy >  -0.79
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.72
# |   |   |   |   |   |   |   |   |   |--- tempo <= -0.42
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- tempo >  -0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- energy >  0.21
# |   |   |   |   |   |   |   |--- loudness <= 0.71
# |   |   |   |   |   |   |   |   |--- energy <= 0.65
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- energy >  0.65
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loudness >  0.71
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- speechiness >  0.01
# |   |   |   |   |   |   |--- loudness <= -0.14
# |   |   |   |   |   |   |   |--- liveness <= -0.50
# |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |--- liveness >  -0.50
# |   |   |   |   |   |   |   |   |--- loudness <= -0.32
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- loudness >  -0.32
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- loudness >  -0.14
# |   |   |   |   |   |   |   |--- tempo <= 0.28
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.60
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.60
# |   |   |   |   |   |   |   |   |   |--- danceability <= 1.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- danceability >  1.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- tempo >  0.28
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- key >  -0.30
# |   |   |   |   |   |--- danceability <= 1.25
# |   |   |   |   |   |   |--- valence <= 0.67
# |   |   |   |   |   |   |   |--- duration_ms <= -1.29
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- duration_ms >  -1.29
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- valence >  0.67
# |   |   |   |   |   |   |   |--- speechiness <= 0.28
# |   |   |   |   |   |   |   |   |--- speechiness <= -0.45
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- speechiness >  -0.45
# |   |   |   |   |   |   |   |   |   |--- liveness <= -0.44
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- liveness >  -0.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- speechiness >  0.28
# |   |   |   |   |   |   |   |   |--- valence <= 0.69
# |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- valence >  0.69
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- danceability >  1.25
# |   |   |   |   |   |   |--- valence <= 0.98
# |   |   |   |   |   |   |   |--- valence <= 0.74
# |   |   |   |   |   |   |   |   |--- key <= 0.55
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- key >  0.55
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- valence >  0.74
# |   |   |   |   |   |   |   |   |--- danceability <= 1.53
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- danceability >  1.53
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- valence >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- valence >  0.98
# |   |   |   |   |   |   |   |--- class: 1
# |   |--- valence >  1.19
# |   |   |--- valence <= 1.24
# |   |   |   |--- danceability <= 0.27
# |   |   |   |   |--- speechiness <= -0.35
# |   |   |   |   |   |--- loudness <= -1.55
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- loudness >  -1.55
# |   |   |   |   |   |   |--- speechiness <= -0.45
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- speechiness >  -0.45
# |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- speechiness >  -0.35
# |   |   |   |   |   |--- class: 3
# |   |   |   |--- danceability >  0.27
# |   |   |   |   |--- liveness <= -0.85
# |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- liveness >  -0.85
# |   |   |   |   |   |--- valence <= 1.23
# |   |   |   |   |   |   |--- speechiness <= -0.29
# |   |   |   |   |   |   |   |--- speechiness <= -0.57
# |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |--- speechiness >  -0.57
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- speechiness >  -0.29
# |   |   |   |   |   |   |   |--- valence <= 1.20
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- valence >  1.20
# |   |   |   |   |   |   |   |   |--- valence <= 1.21
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- valence >  1.21
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- valence >  1.23
# |   |   |   |   |   |   |--- liveness <= -0.53
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- liveness >  -0.53
# |   |   |   |   |   |   |   |--- liveness <= -0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- liveness >  -0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- valence >  1.24
# |   |   |   |--- instrumentalness <= -0.26
# |   |   |   |   |--- duration_ms <= -1.43
# |   |   |   |   |   |--- speechiness <= -0.50
# |   |   |   |   |   |   |--- valence <= 1.41
# |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |--- valence >  1.41
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- speechiness >  -0.50
# |   |   |   |   |   |   |--- instrumentalness <= -0.29
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- instrumentalness >  -0.29
# |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- duration_ms >  -1.43
# |   |   |   |   |   |--- danceability <= 0.51
# |   |   |   |   |   |   |--- energy <= 1.50
# |   |   |   |   |   |   |   |--- valence <= 1.45
# |   |   |   |   |   |   |   |   |--- liveness <= -0.79
# |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |--- liveness >  -0.79
# |   |   |   |   |   |   |   |   |   |--- key <= -1.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- key >  -1.14
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- valence >  1.45
# |   |   |   |   |   |   |   |   |--- tempo <= 0.92
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- tempo >  0.92
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- energy >  1.50
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- danceability >  0.51
# |   |   |   |   |   |   |--- duration_ms <= -1.13
# |   |   |   |   |   |   |   |--- loudness <= 0.12
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loudness >  0.12
# |   |   |   |   |   |   |   |   |--- valence <= 1.32
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- valence >  1.32
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- duration_ms >  -1.13
# |   |   |   |   |   |   |   |--- loudness <= -0.61
# |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |--- loudness >  -0.61
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- instrumentalness >  -0.26
# |   |   |   |   |--- instrumentalness <= 0.09
# |   |   |   |   |   |--- danceability <= 1.38
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- danceability >  1.38
# |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |--- instrumentalness >  0.09
# |   |   |   |   |   |--- tempo <= 0.36
# |   |   |   |   |   |   |--- speechiness <= -0.61
# |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |--- speechiness >  -0.61
# |   |   |   |   |   |   |   |--- instrumentalness <= 0.35
# |   |   |   |   |   |   |   |   |--- loudness <= -0.81
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loudness >  -0.81
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- instrumentalness >  0.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- tempo >  0.36
# |   |   |   |   |   |   |--- valence <= 1.32
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- valence >  1.32
# |   |   |   |   |   |   |   |--- loudness <= -0.31
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- loudness >  -0.31
# |   |   |   |   |   |   |   |   |--- class: 2
# |--- duration_ms >  -0.94
# |   |--- duration_ms <= -0.23
# |   |   |--- loudness <= 0.25
# |   |   |   |--- danceability <= 0.33
# |   |   |   |   |--- valence <= -0.81
# |   |   |   |   |   |--- danceability <= -0.53
# |   |   |   |   |   |   |--- duration_ms <= -0.49
# |   |   |   |   |   |   |   |--- loudness <= -0.16
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.93
# |   |   |   |   |   |   |   |   |   |--- valence <= -1.12
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 1.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  1.74
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- valence >  -1.12
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.93
# |   |   |   |   |   |   |   |   |   |--- tempo <= -1.08
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- tempo >  -1.08
# |   |   |   |   |   |   |   |   |   |   |--- mode <= -0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- mode >  -0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- loudness >  -0.16
# |   |   |   |   |   |   |   |   |--- duration_ms <= -0.85
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.86
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 1.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- energy >  1.26
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.86
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- duration_ms >  -0.85
# |   |   |   |   |   |   |   |   |   |--- liveness <= -0.39
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= -1.46
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  -1.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- liveness >  -0.39
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- duration_ms >  -0.49
# |   |   |   |   |   |   |   |--- speechiness <= -0.69
# |   |   |   |   |   |   |   |   |--- energy <= -2.48
# |   |   |   |   |   |   |   |   |   |--- energy <= -2.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |--- energy >  -2.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |--- energy >  -2.48
# |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.71
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -1.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.71
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -1.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -1.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- speechiness >  -0.69
# |   |   |   |   |   |   |   |   |--- danceability <= -1.84
# |   |   |   |   |   |   |   |   |   |--- key <= -1.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- key >  -1.29
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= -2.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  -2.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- danceability >  -1.84
# |   |   |   |   |   |   |   |   |   |--- valence <= -1.38
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- valence >  -1.38
# |   |   |   |   |   |   |   |   |   |   |--- energy <= -2.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- energy >  -2.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- danceability >  -0.53
# |   |   |   |   |   |   |--- energy <= -1.03
# |   |   |   |   |   |   |   |--- danceability <= 0.11
# |   |   |   |   |   |   |   |   |--- liveness <= -0.08
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= -0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  -0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= -0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  -0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- liveness >  -0.08
# |   |   |   |   |   |   |   |   |   |--- key <= 1.12
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- key >  1.12
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- danceability >  0.11
# |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |--- valence <= -1.60
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |--- valence >  -1.60
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 2.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- acousticness >  2.34
# |   |   |   |   |   |   |   |   |   |   |--- energy <= -1.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- energy >  -1.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- energy >  -1.03
# |   |   |   |   |   |   |   |--- energy <= 1.12
# |   |   |   |   |   |   |   |   |--- duration_ms <= -0.49
# |   |   |   |   |   |   |   |   |   |--- danceability <= -0.35
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- danceability >  -0.35
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- duration_ms >  -0.49
# |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.95
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.95
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= -1.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  -1.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- energy >  1.12
# |   |   |   |   |   |   |   |   |--- speechiness <= -0.57
# |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |--- speechiness >  -0.57
# |   |   |   |   |   |   |   |   |   |--- energy <= 1.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- energy >  1.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- valence >  -0.81
# |   |   |   |   |   |--- speechiness <= 0.39
# |   |   |   |   |   |   |--- acousticness <= -0.94
# |   |   |   |   |   |   |   |--- acousticness <= -0.98
# |   |   |   |   |   |   |   |   |--- speechiness <= -0.33
# |   |   |   |   |   |   |   |   |   |--- duration_ms <= -0.70
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- duration_ms >  -0.70
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= -1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  -1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- speechiness >  -0.33
# |   |   |   |   |   |   |   |   |   |--- tempo <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- tempo >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# ...
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- key >  0.84
# |   |   |   |   |   |   |   |   |   |   |--- liveness <= 0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- liveness >  0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.98
# |   |   |   |   |   |   |   |   |   |--- loudness <= 0.86
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- loudness >  0.86
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- danceability >  0.39
# |   |   |   |   |   |   |   |--- duration_ms <= 0.13
# |   |   |   |   |   |   |   |   |--- valence <= 0.11
# |   |   |   |   |   |   |   |   |   |--- valence <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- valence >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 1.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  1.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- valence >  0.11
# |   |   |   |   |   |   |   |   |   |--- loudness <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- loudness >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- duration_ms >  0.13
# |   |   |   |   |   |   |   |   |--- valence <= 1.02
# |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- acousticness >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- key <= -1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- key >  -1.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- valence >  1.02
# |   |   |   |   |   |   |   |   |   |--- tempo <= -0.70
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |   |--- valence >  1.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- tempo >  -0.70
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |--- speechiness >  -0.17
# |   |   |   |   |   |--- duration_ms <= 0.33
# |   |   |   |   |   |   |--- danceability <= 1.50
# |   |   |   |   |   |   |   |--- tempo <= -0.36
# |   |   |   |   |   |   |   |   |--- duration_ms <= 0.01
# |   |   |   |   |   |   |   |   |   |--- danceability <= 1.47
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- danceability >  1.47
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- duration_ms >  0.01
# |   |   |   |   |   |   |   |   |   |--- tempo <= -1.65
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= -1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  -1.66
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- tempo >  -1.65
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= 0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- tempo >  -0.36
# |   |   |   |   |   |   |   |   |--- tempo <= 0.51
# |   |   |   |   |   |   |   |   |   |--- tempo <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- tempo >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- tempo >  0.51
# |   |   |   |   |   |   |   |   |   |--- liveness <= -0.80
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- liveness >  -0.80
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- danceability >  1.50
# |   |   |   |   |   |   |   |--- tempo <= -0.77
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.81
# |   |   |   |   |   |   |   |   |   |--- tempo <= -1.14
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- tempo >  -1.14
# |   |   |   |   |   |   |   |   |   |   |--- valence <= 0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- valence >  0.87
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.81
# |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.66
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- speechiness >  0.66
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- tempo >  -0.77
# |   |   |   |   |   |   |   |   |--- liveness <= -0.35
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.13
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 7
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.13
# |   |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- liveness >  -0.35
# |   |   |   |   |   |   |   |   |   |--- tempo <= -0.31
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- tempo >  -0.31
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- energy >  0.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |--- duration_ms >  0.33
# |   |   |   |   |   |   |--- tempo <= -0.67
# |   |   |   |   |   |   |   |--- instrumentalness <= -0.32
# |   |   |   |   |   |   |   |   |--- danceability <= 1.41
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.93
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.93
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= -1.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  -1.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- danceability >  1.41
# |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.67
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 1.44
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  1.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.67
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 1.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  1.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- instrumentalness >  -0.32
# |   |   |   |   |   |   |   |   |--- acousticness <= -0.98
# |   |   |   |   |   |   |   |   |   |--- key <= 0.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- key >  0.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 6
# |   |   |   |   |   |   |   |   |--- acousticness >  -0.98
# |   |   |   |   |   |   |   |   |   |--- danceability <= 1.16
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- duration_ms >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- danceability >  1.16
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  1.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- tempo >  -0.67
# |   |   |   |   |   |   |   |--- tempo <= 0.05
# |   |   |   |   |   |   |   |   |--- tempo <= 0.04
# |   |   |   |   |   |   |   |   |   |--- danceability <= -0.30
# |   |   |   |   |   |   |   |   |   |   |--- energy <= 1.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- energy >  1.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- danceability >  -0.30
# |   |   |   |   |   |   |   |   |   |   |--- danceability <= 0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- danceability >  0.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- tempo >  0.04
# |   |   |   |   |   |   |   |   |   |--- valence <= -0.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- valence >  -0.84
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- tempo >  0.05
# |   |   |   |   |   |   |   |   |--- loudness <= 0.67
# |   |   |   |   |   |   |   |   |   |--- instrumentalness <= -0.29
# |   |   |   |   |   |   |   |   |   |   |--- valence <= -0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- valence >  -0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- instrumentalness >  -0.29
# |   |   |   |   |   |   |   |   |   |   |--- tempo <= 1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- tempo >  1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- loudness >  0.67
# |   |   |   |   |   |   |   |   |   |--- acousticness <= -0.34
# |   |   |   |   |   |   |   |   |   |   |--- loudness <= 0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- loudness >  0.74
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- acousticness >  -0.34
# |   |   |   |   |   |   |   |   |   |   |--- speechiness <= 2.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- speechiness >  2.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7

# %%
from sklearn import tree
fig = plt.figure(figsize=(35,35))
dt_plot = tree.plot_tree(dtc,
                   feature_names=X.columns,
                   filled=True, fontsize=13,precision=0)
plt.savefig('tree_plot',dpi=100)

# %% [markdown]
# ### Checking for over-under fitting.

# %%
train_predictions = decision_tree_model.predict(X_train)
test_predictions = decision_tree_model.predict(X_test)

# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average='weighted')
val_precision - precision_score(label_val, val_predictions, average='weighted')
# Evaluate precision on the test set
test_precision = precision_score(label_test, test_predictions, average='weighted')

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Test Data:", test_precision)
print("Precision on Validation Data:", val_precision)
# Out:
# Precision on Train Data: 0.9756755401240554
# Precision on Test Data: 0.952573432670906
# Precision on Validation Data: 0.989307351537379

# %% [markdown]
# ### Random Forest

# %%
random_forest_model = RandomForestClassifier(n_estimators=21, random_state=42
                                             , max_features='sqrt'
                                             )
### 21 n_estimators gives best accuracy
## sqrt or log2 give same accuracy
random_forest_model.fit(X_train, label_train)

# Make predictions on the test set
val_predictions = random_forest_model.predict(X_val)

# Evaluate the model
val_accuracy = accuracy_score(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)


# Print the results
print("Validation Accuracy:", val_accuracy)
print("Classification Report:")
print(classification_rep)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# C:\Users\asold\AppData\Local\Temp\ipykernel_20164\3182869589.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest_model.fit(X_train, label_train)
# Validation Accuracy: 0.9890623948307196
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      3813
#            1       1.00      0.93      0.96      3653
#            2       1.00      1.00      1.00      3675
#            3       1.00      1.00      1.00      3662
#            4       1.00      1.00      1.00      3697
#            5       0.99      1.00      1.00      3683
#            6       0.99      1.00      1.00      3700
#            7       0.98      1.00      0.99      3831
#
#     accuracy                           0.99     29714
#    macro avg       0.99      0.99      0.99     29714
# weighted avg       0.99      0.99      0.99     29714
#
# Confusion Matrix:
# [[3763   12    0    0    0    4   16   18]
#  [ 191 3390    0    0    0   11   14   47]
#  [   0    0 3675    0    0    0    0    0]
#  [   0    0    0 3662    0    0    0    0]
#  [   0    0    0    0 3697    0    0    0]
#  [   0    0    0    0    0 3683    0    0]
#  [   0    0    0    0    0    0 3700    0]
#  [   0    0    0    0    0    6    6 3819]]

# %% [markdown]
# ### Checking for over-under fitting. This model is slightly overfitting

# %%
train_predictions = random_forest_model.predict(X_train)
test_predictions = random_forest_model.predict(X_test)

# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average='weighted')
val_precision = precision_score(label_val, val_predictions, average='weighted')
# Evaluate precision on the test set
test_precision = precision_score(label_test, test_predictions, average='weighted')

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Test Data:", test_precision)
print("Precision on Validation Data:", val_precision)
# Out:
# Precision on Train Data: 0.9983494225983748
# Precision on Test Data: 0.9899007944879554
# Precision on Validation Data: 0.989307351537379

# %% [markdown]
# #### Predictions on Random Forest

# %%
relevant_data
# Out:
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                    66            pop                  dance pop
# 1                    67            pop                  dance pop
# 2                    70            pop                  dance pop
# 3                    60            pop                  dance pop
# 4                    69            pop                  dance pop
# ...                 ...            ...                        ...
# 32828                42            edm  progressive electro house
# 32829                20            edm  progressive electro house
# 32830                14            edm  progressive electro house
# 32831                15            edm  progressive electro house
# 32832                27            edm  progressive electro house
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634     1       0.0583      0.102000
# 1             0.726   0.815   11    -4.969     1       0.0373      0.072400
# 2             0.675   0.931    1    -3.432     0       0.0742      0.079400
# 3             0.718   0.930    7    -3.778     1       0.1020      0.028700
# 4             0.650   0.833    1    -4.672     1       0.0359      0.080300
# ...             ...     ...  ...       ...   ...          ...           ...
# 32828         0.428   0.922    2    -1.814     1       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462     1       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899     0       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361     1       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms decade
# 0              0.000000    0.0653   0.5180  122.036       194754  2010s
# 1              0.004210    0.3570   0.6930   99.972       162600  2010s
# 2              0.000023    0.1100   0.6130  124.008       176616  2010s
# 3              0.000009    0.2040   0.2770  121.956       169093  2010s
# 4              0.000000    0.0833   0.7250  123.976       189052  2010s
# ...                 ...       ...      ...      ...          ...    ...
# 32828          0.000000    0.0668   0.2100  128.170       204375  2010s
# 32829          0.004270    0.3750   0.4000  128.041       353120  2010s
# 32830          0.000001    0.1500   0.4360  127.989       210112  2010s
# 32831          0.127000    0.3430   0.3080  128.008       367432  2010s
# 32832          0.341000    0.7420   0.0894  127.984       337500  2010s
#
# [32833 rows x 16 columns]

# %%
# random_song = np.array([0.564,    0.932,    11,    -10.068,    1,    0.0554,    0.013,    0.169,    0.349,    0.619,    112.937,    146250])
random_song = np.array([0.31,	0.7,	9,	-5.678,	1,	0.047,	0.011,	0.00965,	0.0828,	0.763,	188.386,	255493])

random_song = random_song.reshape(1,-1)
random_song_scaled = scaler.transform(random_song)
prediction = random_forest_model.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['80s'], dtype=object)

# %% [markdown]
# ### Support Vector Machines

# %%
svm_model = SVC(kernel='rbf', C=1, random_state=42)
## the higher the C parameter is, the higher is the penalty for missclassification. If C is lower, then misclassification is allowed more.
## poly works better than others
## sigmoid performs worst

# The 'kernel' parameter of SVC must be a str among {'linear', 'poly', 'sigmoid', 'rbf', 'precomputed'}

svm_model.fit(X_train, label_train)

val_predictions = svm_model.predict(X_val)

# Make predictions on the test set
# predictions = svm_model.predict(X_test)

# Evaluate the model
val_accuracy = accuracy_score(label_val, val_predictions)
conf_matrix = confusion_matrix(label_val, val_predictions)
classification_rep = classification_report(label_val, val_predictions)

# Print the results
print("Accuracy:", val_accuracy)
print("Classification Report:")
print(classification_rep)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.7509927980076732
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.53      0.55      3813
#            1       0.66      0.50      0.57      3653
#            2       0.74      0.82      0.78      3675
#            3       1.00      1.00      1.00      3662
#            4       0.92      0.99      0.96      3697
#            5       0.72      0.83      0.77      3683
#            6       0.67      0.74      0.70      3700
#            7       0.69      0.61      0.65      3831
#
#     accuracy                           0.75     29714
#    macro avg       0.75      0.75      0.75     29714
# weighted avg       0.75      0.75      0.75     29714
#
# Confusion Matrix:
# [[2010  393  200    1   44  284  354  527]
#  [ 599 1834  750    0   25  123  146  176]
#  [ 184  294 3017    0   12   50   65   53]
#  [   0    0    0 3662    0    0    0    0]
#  [   0    0    0    0 3674   23    0    0]
#  [  72   49   40    0  109 3051  324   38]
#  [ 152   66   18    0   64  439 2728  233]
#  [ 475  144   69    0   59  289  456 2339]]

# %%
# Out:
# Accuracy: 0.7509927980076732

# %% [markdown]
# ### Checking for over/under fitting

# %%
train_predictions = svm_model.predict(X_train)
test_predictions = svm_model.predict(X_test)

# Evaluate precision on the training set
train_precision = precision_score(label_train, train_predictions, average='weighted')
val_precision = precision_score(label_val, val_predictions, average='weighted')
# Evaluate precision on the test set
test_precision = precision_score(label_test, test_predictions, average='weighted')

# Print the precision on train and test data
print("Precision on Train Data:", train_precision)
print("Precision on Test Data:", test_precision)
print("Precision on Validation Data:", val_precision)
# Out:
# Precision on Train Data: 0.7573879188049517
# Precision on Test Data: 0.7540655098891593
# Precision on Validation Data: 0.745754856922211

# %% [markdown]
# # 6. Fine-tuning the system.
#
# #### The main technique to fine-tune the system was to resample for minor classes. This actually brought major changes to the performance of most models
#
# ## KNN:
# #### New Accuracy: 96%
#
# ## NB:
# #### New Accuracy: 38%
#
# ## Logistic regression:
# #### New Accuracy : 47%
#
# ## Decision Trees:
# #### New Accuracy: 52%
#
#
# ## Random Forest:
# #### New Accuracy: 99%
#
# ## Support Vector machines:
# #### New Accuracy: 85%
#
# #### In conclusion, we can see that the resampling technique improves the performance of the models that actually matter, and which could be used by the customer.

# %%
random_song = np.array([0.832,	0.838,	1,	-5.414,	0,	0.0421,	0.0791,	0,	0.152,	0.965,	100.021,	218733])

random_song = random_song.reshape(1,-1)
random_song_scaled = scaler.transform(random_song)

# prediction
# Out:
# C:\Users\asold\Documents\VIA\7thSemester\MAL\notebooks\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#knn
prediction = knn_test.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['90s'], dtype=object)

# %%
#Naive bayes
prediction = nb.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['2000s'], dtype=object)

# %%
#Logistic regression
prediction = logistic_regression_model.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['2000s'], dtype=object)

# %%
#Decision Tree
prediction = decision_tree_model.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['90s'], dtype=object)

# %%
#Random Forest
prediction = random_forest_model.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['90s'], dtype=object)

# %%
#SVM
prediction = svm_model.predict(random_song_scaled)
predicted_label = label_encoder1.inverse_transform(prediction)
predicted_label
# Out:
# array(['2000s'], dtype=object)

# %% [markdown]
# # Video presentation can be found here:
# https://youtu.be/_jmUW1Er4vU
